# %%
import pandas as pd
import numpy as np
import model_evaluation_utils as meu
from sklearn.model_selection import train_test_split
import LoggerYN as YN

import time

import datetime

import pandas as pd
import numpy as np
from sklearn.model_selection import *
from sklearn.linear_model import *
from sklearn.preprocessing import *
from sklearn.metrics import *
import sklearn
from sklearn import linear_model
from sklearn import tree 
from sklearn import ensemble

# %%
df = pd.read_csv('phpvcoG8S', sep=None,engine='python', header=0)

# %%
df.dtypes
# Out:
# Airline        object
# Flight          int64
# AirportFrom    object
# AirportTo      object
# DayOfWeek       int64
# Time            int64
# Length          int64
# Delay           int64
# dtype: object

# %%
df.describe(include='all')
# Out:
#        Airline         Flight AirportFrom AirportTo      DayOfWeek  \
# count   539383  539383.000000      539383    539383  539383.000000
# unique      18            NaN         293       293            NaN
# top         WN            NaN         ATL       ATL            NaN
# freq     94097            NaN       34449     34440            NaN
# mean       NaN    2427.928630         NaN       NaN       3.929668
# std        NaN    2067.429837         NaN       NaN       1.914664
# min        NaN       1.000000         NaN       NaN       1.000000
# 25%        NaN     712.000000         NaN       NaN       2.000000
# 50%        NaN    1809.000000         NaN       NaN       4.000000
# 75%        NaN    3745.000000         NaN       NaN       5.000000
# max        NaN    7814.000000         NaN       NaN       7.000000
#
#                  Time         Length          Delay
# count   539383.000000  539383.000000  539383.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean       802.728963     132.202007       0.445442
# std        278.045911      70.117016       0.497015
# min         10.000000       0.000000       0.000000
# 25%        565.000000      81.000000       0.000000
# 50%        795.000000     115.000000       0.000000
# 75%       1035.000000     162.000000       1.000000
# max       1439.000000     655.000000       1.000000

# %%
df.Delay.value_counts()
# Out:
# 0    299119
# 1    240264
# Name: Delay, dtype: int64

# %%
# In[6]:




df.describe(include='all')


# In[8]:


df.dtypes


# In[9]:


df["AirportFrom"] = df["AirportFrom"].astype('category').cat.codes
df["Airline"] = df["Airline"].astype('category').cat.codes
df["AirportTo"] = df["AirportTo"].astype('category').cat.codes
df.dtypes
# Out:
# Airline         int8
# Flight         int64
# AirportFrom    int16
# AirportTo      int16
# DayOfWeek      int64
# Time           int64
# Length         int64
# Delay          int64
# dtype: object

# %%
df.shape
# Out:
# (539383, 8)

# %%
X = df.drop('Delay',axis=1)
y = df.pop('Delay')


X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.80,random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
from sklearn.svm import SVC


DT = DecisionTreeClassifier()
LR = LogisticRegression(n_jobs=-1,max_iter=1000000)
RF = RandomForestClassifier(n_jobs=-1)
XGB = xgb.XGBClassifier(n_jobs=-1)
KNN = KNeighborsClassifier(n_jobs=-1)
class_labels = list(set(y))

# %%
# # Linear Model

memT,cpuT,gpuT = YN.StartLogger("Dataset_S_Instance_M","LinearModel_DT")
start = time.time()
DT.fit(X_train,y_train)
predictions = DT.predict(X_test)
meu.display_model_performance_metrics(true_labels=y_test, predicted_labels=predictions, classes=class_labels)
end = time.time()
YN.EndLogger(memT,cpuT,gpuT)
print("total time Linear Model Decision Tree ", str(datetime.timedelta(seconds=end-start)))

# # Linear Model

memT,cpuT,gpuT = YN.StartLogger("Dataset_S_Instance_M","LinearModel_LR")
start = time.time()
LR.fit(X_train,y_train)
predictions = LR.predict(X_test)
meu.display_model_performance_metrics(true_labels=y_test, predicted_labels=predictions, classes=class_labels)
end = time.time()
YN.EndLogger(memT,cpuT,gpuT)
print("total time Linear Model Logistic Regression", str(datetime.timedelta(seconds=end-start)))




memT,cpuT,gpuT = YN.StartLogger("Dataset_S_Instance_M","LinearModel_KNN")
start = time.time()
KNN.fit(X_train,y_train)
predictions = KNN.predict(X_test)
meu.display_model_performance_metrics(true_labels=y_test, predicted_labels=predictions, classes=class_labels)
end = time.time()
YN.EndLogger(memT,cpuT,gpuT)
print("total time Linear Model KNN", str(datetime.timedelta(seconds=end-start)))
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.6089
# Precision: 0.6045
# Recall: 0.6089
# F1 Score: 0.6034
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.63      0.71      0.67     60014
#            1       0.57      0.48      0.52     47863
#
#     accuracy                           0.61    107877
#    macro avg       0.60      0.60      0.59    107877
# weighted avg       0.60      0.61      0.60    107877
#
# total time Linear Model Decision Tree  0:00:03.451088
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.5847
# Precision: 0.5769
# Recall: 0.5847
# F1 Score: 0.5666
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.60      0.76      0.67     60014
#            1       0.55      0.36      0.43     47863
#
#     accuracy                           0.58    107877
#    macro avg       0.57      0.56      0.55    107877
# weighted avg       0.58      0.58      0.57    107877
#
# total time Linear Model Logistic Regression 0:00:09.491884
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.6422
# Precision: 0.6401
# Recall: 0.6422
# F1 Score: 0.6405
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69     60014
#            1       0.60      0.56      0.58     47863
#
#     accuracy                           0.64    107877
#    macro avg       0.64      0.63      0.63    107877
# weighted avg       0.64      0.64      0.64    107877
#
# total time Linear Model KNN 0:00:05.499696

# %%
# In[18]:
start = time.time()
memT,cpuT,gpuT = YN.StartLogger("Dataset_S_Instance_M","Non-LinearModel_RF")
RF.fit(X_train,y_train)
predictions = RF.predict(X_test)
meu.display_model_performance_metrics(true_labels=y_test, predicted_labels=predictions, classes=class_labels)
end = time.time()
YN.EndLogger(memT,cpuT,gpuT)
print("total time Non-Linear Model RF", str(datetime.timedelta(seconds=end-start)))


start = time.time()
memT,cpuT,gpuT = YN.StartLogger("Dataset_S_Instance_M","Non-LinearModel_XGB")
XGB.fit(X_train,y_train)
predictions = XGB.predict(X_test)
meu.display_model_performance_metrics(true_labels=y_test, predicted_labels=predictions, classes=class_labels)
end = time.time()
YN.EndLogger(memT,cpuT,gpuT)
print("total time Non-Linear Model XGB", str(datetime.timedelta(seconds=end-start)))
# Out:
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.6182
# Precision: 0.6173
# Recall: 0.6182
# F1 Score: 0.6177
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66     60014
#            1       0.57      0.56      0.56     47863
#
#     accuracy                           0.62    107877
#    macro avg       0.61      0.61      0.61    107877
# weighted avg       0.62      0.62      0.62    107877
#
# total time Non-Linear Model RF 0:01:07.624628
# Model Performance metrics:
# ------------------------------
# Accuracy: 0.6674
# Precision: 0.6669
# Recall: 0.6674
# F1 Score: 0.6593
#
# Model Classification report:
# ------------------------------
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73     60014
#            1       0.66      0.51      0.57     47863
#
#     accuracy                           0.67    107877
#    macro avg       0.67      0.65      0.65    107877
# weighted avg       0.67      0.67      0.66    107877
#
# total time Non-Linear Model XGB 0:00:38.236509
